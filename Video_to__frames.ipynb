# %%
import cv2
import time
import os
from os import listdir

def video_to_frames(input_loc, output_loc):
    """Function to extract frames from input video file
    and save them as separate frames in an output directory.
    Args:
        input_loc: Input video file.
        output_loc: Output directory to save the frames.
    Returns:
        None
    """
    try:
        os.mkdir(output_loc)
    except OSError:
        pass
    # Log the time
    time_start = time.time()
    # Start capturing the feed
    cap = cv2.VideoCapture(input_loc)
    # Find the number of frames
    video_length = int(cap.get(cv2.CAP_PROP_FRAME_COUNT)) - 1
    print ("Number of frames: ", video_length)
    count = 0
    print ("Converting video..\n")
    # Start converting the video
    while cap.isOpened():
        # Extract the frame
        ret, frame = cap.read()
        # Write the results back to output location.
        cv2.imwrite(output_loc +"/%#05d.jpg" % (count+1), frame)
        count = count + 1
        # If there are no more frames left
        if (count > (video_length-1)):
            # Log the time again
            time_end = time.time()
            # Release the feed
            cap.release()
            # Print stats
            print ("Done extracting frames.\n%d frames extracted" % count)
            print ("It took %d seconds forconversion." % (time_end-time_start))
            break

if __name__=="__main__":
    
    input_folder= "C:/Users/anoos/Desktop/Unmasked2"
    output_folder="C:/Users/anoos/Desktop/frames unmasked"
    for filename in listdir(input_folder):
        input_loc = input_folder+ "/"+filename
        new_path = os.path.join(output_folder, filename)
        os.mkdir(new_path)
        output_loc = output_folder+"/"+filename
        for video in listdir(input_loc):
            input_loc1=input_loc+"/"+video
            video_to_frames(input_loc1, output_loc)
# Out:
# Number of frames:  236
# Converting video..
#
# Done extracting frames.
# 236 frames extracted
# It took 16 seconds forconversion.
# Number of frames:  94
# Converting video..
#
# Done extracting frames.
# 94 frames extracted
# It took 7 seconds forconversion.
# Number of frames:  179
# Converting video..
#
# Done extracting frames.
# 179 frames extracted
# It took 23 seconds forconversion.
# Number of frames:  255
# Converting video..
#
# Done extracting frames.
# 255 frames extracted
# It took 35 seconds forconversion.
# Number of frames:  287
# Converting video..
#
# Done extracting frames.
# 287 frames extracted
# It took 71 seconds forconversion.
# Number of frames:  -1
# Converting video..
#
# Number of frames:  290
# Converting video..
#
# Done extracting frames.
# 290 frames extracted
# It took 21 seconds forconversion.
# Number of frames:  270
# Converting video..
#
# Done extracting frames.
# 270 frames extracted
# It took 10 seconds forconversion.
# Number of frames:  263
# Converting video..
#
# Done extracting frames.
# 263 frames extracted
# It took 38 seconds forconversion.
# Number of frames:  219
# Converting video..
#
# Done extracting frames.
# 219 frames extracted
# It took 39 seconds forconversion.
